# %% [markdown]
# Mon premier NoteBook

# %% [markdown]
# ![Jupiter](https://upload.wikimedia.org/wikipedia/commons/thumb/3/38/Jupyter_logo.svg/220px-Jupyter_logo.svg.png)

# %% [markdown]
# Le château

# %% [markdown]
# ![essai2](data:image/jpeg;base64,...)

# %%
U=int(input("Entrer la valeur de u "))
n=0
while U>=0:
    U=U-2
    n=n+1
print(n)
# Out:
# Entrer la valeur de u 25
# 13
